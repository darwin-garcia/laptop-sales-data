# %% [markdown]
# # **Venta de Portatiles (Analisis Exploratorio de Datos y Machine Learning)**

# %% [markdown]
# # Objetivos
#
# Al terminar esta practica, podemos:
#
#  - Importar un dataset desde un archivo CSV file a un Dataframe de Pandas
#  - Desarrollar algunos conocimientos básicos sobre el conjunto de datos (Dataset).
#  - Visualizar patrones de características individuales.
#  - Realizar análisis estadísticos descriptivos en el conjunto de datos.
#  - Utilizar grupos y tablas dinámicas para determinar el efecto de las variables categóricas en el precio.
#  - Utilizar la correlación de Pearson para medir la interdependencia entre variables.

# %% [markdown]
# Usaremos un dataframe de practica (IBM Course)

# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib

# %%
# Pandas es una biblioteca de software escrita para el lenguaje de programación Python para la manipulación y el análisis de datos.
import pandas as pd
# NumPy es una biblioteca para el lenguaje de programación Python que añade compatibilidad con matrices y matrices multidimensionales de gran tamaño, junto con una amplia colección de funciones matemáticas de alto nivel para operar con estas matrices.
import numpy as np
# Matplotlib es una biblioteca de gráficos para Python y pyplot nos proporciona un marco de trabajo para gráficos similar al de MatLab. Lo utilizaremos en nuestra función plotter para trazar datos.
import matplotlib.pyplot as plt
# Seaborn es una biblioteca de visualización de datos de Python basada en matplotlib. Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos.
import seaborn as sns

# %%
ruta = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"
df=pd.read_csv(ruta)
